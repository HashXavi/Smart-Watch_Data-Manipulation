# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Reading and opening file

# %%
df = pd.read_csv(r"C:\Users\PMLS\Downloads\unclean_smartwatch_health_data.csv")

# %%
df
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1         NaN               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# 4      2130.0         61.950165               98.583797  15679.067648
# ...       ...               ...                     ...           ...
# 9995   1524.0         78.819386               98.931927   2948.491953
# 9996   4879.0         48.632659               95.773035   4725.623070
# 9997   2624.0         73.834442               97.945874   2571.492060
# 9998   4907.0               NaN               98.401058   3364.788855
# 9999   4113.0         70.063864               98.475606    544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 0         7.167235622316564  Highly Active            1
# ...

# %% [markdown]
# ## Checking Null/Non-Null Values, data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   object
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %% [markdown]
# ### CHECKING OUT PERCANTAGE  OF  NULL OR NAN VALUES

# %%
null_val = df.isna().sum()/ len(df)
null_val
# Out:
# User ID                   0.0201
# Heart Rate (BPM)          0.0400
# Blood Oxygen Level (%)    0.0300
# Step Count                0.0100
# Sleep Duration (hours)    0.0150
# Activity Level            0.0200
# Stress Level              0.0200
# dtype: float64

# %% [markdown]
# ### CHECKING SPELLINGS ERRORS AND IMPROPER SYNTAX

# %%
df.head(10)
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
# 5   2095.0         96.285938               94.202910  10205.992256
# 6   4772.0         47.272257               95.389760   3208.781177
# 7   4092.0         81.733497               95.981343   6051.249857
# 8   3979.0         93.340338               97.218945   1775.029578
# 9   3169.0         51.409967               97.272787   7940.021452
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# ...

# %%
df['Activity Level'].value_counts()  #BEFORE
# Out:
# Activity Level
# Seddentary       1676
# Sedentary        1657
# Highly Active    1650
# Active           1643
# Actve            1622
# Highly_Active    1552
# Name: count, dtype: int64

# %%
df['Activity Level'].value_counts() #AFTER
# Out:
# Activity Level
# Sedentary        3333
# Active           3265
# Highly Active    3202
# Name: count, dtype: int64

# %% [markdown]
# ## CORRECTING SPELLINGS MISTAKES IN ACTIVITY COLUMN

# %%
df['Activity Level'] = df['Activity Level'].replace("Seddentary","Sedentary")
df['Activity Level'] = df['Activity Level'].replace("Highly_Active","Highly Active")
df['Activity Level'] = df['Activity Level'].replace("Actve","Active")

# %% [markdown]
#  ### Filling NaN

# %%
df['Sleep Duration (hours)'] = df['Sleep Duration (hours)'].str.strip()

# %%
df['Sleep Duration (hours)'] = pd.to_numeric(df['Sleep Duration (hours)'],errors='coerce')

# %%
df['Sleep Duration (hours)'] = df['Sleep Duration (hours)'].replace({'ERROR':0.0})

# %%
df.head(20)
# Out:
#     User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0    4174.0         58.939776               98.809650   5450.390578
# 1       NaN               NaN               98.532195    727.601610
# 2    1860.0        247.803052               97.052954   2826.521994
# 3    2294.0         40.000000               96.894213  13797.338044
# 4    2130.0         61.950165               98.583797  15679.067648
# 5    2095.0         96.285938               94.202910  10205.992256
# 6    4772.0         47.272257               95.389760   3208.781177
# 7    4092.0         81.733497               95.981343   6051.249857
# 8    3979.0         93.340338               97.218945   1775.029578
# 9    3169.0         51.409967               97.272787   7940.021452
# 10   1466.0        101.914938                     NaN   2987.568640
# 11   2238.0         73.852941               95.399440   1748.197069
# 12   1330.0         95.372290               99.152652   6155.837342
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9603 non-null   float64
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 547.0+ KB

# %%
df['Activity Level'] = df['Activity Level'].dropna()

# %% [markdown]
# ### INSTEAD OF DROPPING ZEROS TAKING MEDIAN TO MAKE DATA MORE CONVINENT

# %%
df = df.fillna(df['Heart Rate (BPM)'].median())

# %%
df = df.fillna(df['Blood Oxygen Level (%)'].median())

# %%
p = len(df)
p
# Out:
# 10000

# %%
df['Stress Level']= df['Stress Level'].str.strip()

# %%
df['Stress Level']= pd.to_numeric(df['Stress Level'],errors='coerce')

# %%
df['Stress Level'] = df['Stress Level'].fillna(df['Stress Level'].median())

# %%
df = df.fillna(df['Sleep Duration (hours)'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 10000 non-null  float64
#  1   Heart Rate (BPM)        10000 non-null  float64
#  2   Blood Oxygen Level (%)  10000 non-null  float64
#  3   Step Count              10000 non-null  float64
#  4   Sleep Duration (hours)  10000 non-null  float64
#  5   Activity Level          10000 non-null  object
#  6   Stress Level            10000 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 547.0+ KB

# %%
df.describe()
# Out:
#             User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# count  10000.000000      10000.000000            10000.000000  10000.000000
# mean    2948.541834         76.002867               97.162952   6916.581232
# std     1211.029327         19.020902                4.219589   6885.709906
# min       75.220601         40.000000               75.220601      0.910138
# 25%     1946.000000         65.322796               96.496549   1954.281465
# 50%     2960.000000         75.220601               97.933416   4899.902269
# 75%     3985.000000         84.791711               99.327856   9680.097095
# max     4999.000000        296.593970              100.000000  62486.690753
#
#        Sleep Duration (hours)  Stress Level
# count            10000.000000  10000.000000
# mean                 9.233454      5.452500
# std                 13.498889      2.836503
# min                 -0.194453      1.000000
# 25%                  5.541519      3.000000
# ...

# %% [markdown]
# ### ROUNDING OFF TO 2 DECIMAL PLACES

# %%
df['Heart Rate (BPM)'] = df['Heart Rate (BPM)'].round(2)

# %%
df['Blood Oxygen Level (%)'] = df['Blood Oxygen Level (%)'].round(2)

# %%
df['Step Count'] = df['Step Count'].round(2)

# %%
df['Step Count'] = df['Step Count'].round(2)

# %%
df['Sleep Duration (hours)'] = df['Sleep Duration (hours)'].round(2)

# %%
df['Stress Level'] = df['Stress Level'].round(1)

# %%
df['Activity Level'] = df['Activity Level'].round(2)

# %%
df.head(20)
# Out:
#         User ID  Heart Rate (BPM)  Blood Oxygen Level (%)  Step Count  \
# 0   4174.000000             58.94                   98.81     5450.39
# 1     75.220601             75.22                   98.53      727.60
# 2   1860.000000            247.80                   97.05     2826.52
# 3   2294.000000             40.00                   96.89    13797.34
# 4   2130.000000             61.95                   98.58    15679.07
# 5   2095.000000             96.29                   94.20    10205.99
# 6   4772.000000             47.27                   95.39     3208.78
# 7   4092.000000             81.73                   95.98     6051.25
# 8   3979.000000             93.34                   97.22     1775.03
# 9   3169.000000             51.41                   97.27     7940.02
# 10  1466.000000            101.91                   75.22     2987.57
# 11  2238.000000             73.85                   95.40     1748.20
# ...

# %%
df.head(20)
# Out:
#         User ID  Heart Rate (BPM)  Blood Oxygen Level (%)  Step Count  \
# 0   4174.000000             58.94                   98.81     5450.39
# 1     75.220601             75.22                   98.53      727.60
# 2   1860.000000            247.80                   97.05     2826.52
# 3   2294.000000             40.00                   96.89    13797.34
# 4   2130.000000             61.95                   98.58    15679.07
# 5   2095.000000             96.29                   94.20    10205.99
# 6   4772.000000             47.27                   95.39     3208.78
# 7   4092.000000             81.73                   95.98     6051.25
# 8   3979.000000             93.34                   97.22     1775.03
# 9   3169.000000             51.41                   97.27     7940.02
# 10  1466.000000            101.91                   75.22     2987.57
# 11  2238.000000             73.85                   95.40     1748.20
# ...

# %%
df = df.drop(df[df['Sleep Duration (hrs)'] == '0.0'].index)

# %% [markdown]
# ### CREATING A COLUMN TO MEASURE THE STRESS LEVEL

# %%
## using numpy 

conditions = [
    (df['Stress Level']>=1) & (df['Stress Level'] <6),
    (df['Stress Level']>=6) & (df['Stress Level'] <8)

]

choices = ['Excellent','Satisfactory']

df['Stress_Ratings'] = np.select(conditions,choices, default='Bad')

# %%
df['Stress_Ratings'].value_counts()
# Out:
# Stress_Ratings
# Excellent       5146
# Bad             2847
# Satisfactory    2007
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#        User ID  Heart Rate (BPM)  Blood Oxygen Level (%)  Step Count  \
# 0  4174.000000             58.94                   98.81     5450.39
# 1    75.220601             75.22                   98.53      727.60
# 2  1860.000000            247.80                   97.05     2826.52
# 3  2294.000000             40.00                   96.89    13797.34
# 4  2130.000000             61.95                   98.58    15679.07
# 5  2095.000000             96.29                   94.20    10205.99
# 6  4772.000000             47.27                   95.39     3208.78
# 7  4092.000000             81.73                   95.98     6051.25
# 8  3979.000000             93.34                   97.22     1775.03
# 9  3169.000000             51.41                   97.27     7940.02
#
#    Sleep Duration (hours) Activity Level  Stress Level
# 0                    7.17  Highly Active           1.0
# 1                    6.54  Highly Active           5.0
# ...

# %% [markdown]
# #### CREATING COLUMN FOR OVERALL USER RATINGS

# %%
bo_healthy = (df['Blood Oxygen Level (%)']>=94)&(df['Blood Oxygen Level (%)']<100)
bp_healthy = (df['Heart Rate (BPM)']>=50)&(df['Heart Rate (BPM)']<80)
sc_healthy = (df['Step Count']>=4000)&(df['Step Count']<15000)
sleep_health = (df['Sleep Duration (hours)']>=6)&(df['Sleep Duration (hours)']<8)

healty_count = bo_healthy.astype(int) + bp_healthy.astype(int) + sc_healthy.astype(int)+sleep_health.astype(int)

df['User_Ratings'] = np.select(
[healty_count == 4 , healty_count == 3,healty_count == 2],
['Healthy','Mid-Healthy','Boderline'],
default= 'Unhealthy'
)

# %%
df
# Out:
#           User ID  Heart Rate (BPM)  Blood Oxygen Level (%)  Step Count  \
# 0     4174.000000             58.94                   98.81     5450.39
# 1       75.220601             75.22                   98.53      727.60
# 2     1860.000000            247.80                   97.05     2826.52
# 3     2294.000000             40.00                   96.89    13797.34
# 4     2130.000000             61.95                   98.58    15679.07
# ...           ...               ...                     ...         ...
# 9995  1524.000000             78.82                   98.93     2948.49
# 9996  4879.000000             48.63                   95.77     4725.62
# 9997  2624.000000             73.83                   97.95     2571.49
# 9998  4907.000000             75.22                   98.40     3364.79
# 9999  4113.000000             70.06                   98.48      544.70
#
#       Sleep Duration (hours) Activity Level  Stress Level Stress_Ratings  \
# ...

# %%
df['User_Ratings'].value_counts()
# Out:
# User_Ratings
# Boderline      3814
# Mid-Healthy    3277
# Unhealthy      1981
# Healthy         928
# Name: count, dtype: int64

# %% [markdown]
# Saving as CSV

# %%
df.to_csv(r'C:\Users\PMLS\Projects-DA\data.csv', index=False)
